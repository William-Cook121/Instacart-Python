# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Import Ords_prods_merged

df_ords_prods_merged = pd.read_pickle(r'C:\Users\18179\Documents\CareerFoundry\InstaCart Basket Analysis\02 Data\Prepared Data\orders_products_merged.pkl')

# %%
#Slim down data frame
df = df_ords_prods_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 15)

# %%
#Define price range label function

def price_label(row):
    
    if row['prices'] <=5:
        return 'Low-range product'
    elif(row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return 'Not enough data'

# %%
#apply function

df['price_range'] = df.apply(price_label, axis=1)
# Out:
# <ipython-input-6-5aff0983b2a5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
#Using .loc in If-statement
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\18179\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\18179\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid_range_product'
# Out:
# C:\Users\18179\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[df ['prices'] < 5, 'price_range_loc'] = 'Low_range product'
# Out:
# C:\Users\18179\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
#Categorize products using .loc
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid_range_product    756450
# Low_range product    200945
# NaN                   42605
# Name: price_range_loc, dtype: int64

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = "High_range_product"

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid_range_product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] < 5, 'price_range_loc'] = 'Low_range_product'

# %%
#Category products 
df_ords_prods_merged['price_range_loc'].value_counts()
# Out:
# Mid_range_product     21860860
# Low_range_product      9900417
# High_range_product      417678
# Name: price_range_loc, dtype: int64

# %%
#Category of products w/ dropna
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid_range_product     21860860
# Low_range_product      9900417
# High_range_product      417678
# NaN                     225904
# Name: price_range_loc, dtype: int64

# %%
#Rank of busiest DOW
df_ords_prods_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_day_of_week, dtype: int64

# %%
#Create busiest day column

result = []

for value in df_ords_prods_merged['order_day_of_week']:
    if value == 0: 
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regular busy')

# %%
result
# Out:
# ['Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Regular busy',
#  'Busiest day',
# ...

# %%
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regular busy    22416875
# Busiest day      6204182
# Least busy       3783802
# Name: busiest_day, dtype: int64

# %%
#2a. New Busiest/Slowest day columns

result_1 = []

for value in df_ords_prods_merged ['order_day_of_week']:
    if value == 0:
        result_1.append('Busiest days')
    elif value == 1:
        result_1.append('Busiest days')
    elif value == 3:
        result_1.append('Slowest days')
    elif value == 4:
        result_1.append('Slowest days')
    else:
        result_1.append('Regular day')

# %%
df_ords_prods_merged['Busiest Days'] = result_1

# %%
df_ords_prods_merged['Busiest Days'].value_counts(dropna = False)
# Out:
# Regular day     12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: Busiest Days, dtype: int64

# %% [markdown]
# 3a. The amount of regular days decreased by 9.5 million. The amount of busy days increased by nearly 5.6 million
# and the amount of Slowest days doubled.

# %%
#4a. Determine the Busiest hours
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
#13.2 is the average order per hour. 9-16 busiest, 0-6 & 21-23 least orders, 7,8, 17-20 average.
# Out:
# <bound method NDFrame.describe of           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
#4a. execute command for Fewest orders 0,1

df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day']==0) & (df_ords_prods_merged['order_hour_of_day']>=1) & (df_ords_prods_merged['order_hour_of_day']<=6), 'busiest_period_of_day'] = 'Fewest orders'

# %%
#21-23
df_ords_prods_merged.loc[df_ords_prods_merged['order_hour_of_day']>=21, 'busiest_period_of_day'] = 'Fewest orders'

# %%
# Command for Average orders 7,8

df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day']>=7) & (df_ords_prods_merged['order_hour_of_day']<=8), 'busiest_period_of_day'] = 'Average orders'

# %%
#17-20
df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day']>=17) & (df_ords_prods_merged['order_hour_of_day']<=20), 'busiest_period_of_day'] = 'Average orders'

# %%
#Command for Most orders 9-16

df_ords_prods_merged.loc[(df_ords_prods_merged['order_hour_of_day']>=9) & (df_ords_prods_merged['order_hour_of_day']<=16), 'busiest_period_of_day'] = 'Most orders'

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     8567789
# Fewest orders      1832178
# NaN                 886821
# Name: busiest_period_of_day, dtype: int64

# %%
#export as pickle

df_ords_prods_merged.to_pickle(r'C:\Users\18179\Documents\CareerFoundry\InstaCart Basket Analysis\02 Data\orders_products_merged.pkl')

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 19)
