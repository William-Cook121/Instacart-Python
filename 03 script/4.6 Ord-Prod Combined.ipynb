# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
#Import Orders Products Combined Pickle

df_ords_prods = pd.read_pickle(r'C:\Users\18179\Documents\CareerFoundry\InstaCart Basket Analysis\02 Data\Prepared Data\df_ords_prods_combined.pkl')

# %%
df_ords_prods.shape
# Out:
# (32434489, 10)

# %%
df_ords_prods.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
#Import Products DF

df_prods = pd.read_csv(r'C:\Users\18179\Documents\CareerFoundry\InstaCart Basket Analysis\02 Data\Prepared Data\Prods_consistency_check.csv', index_col = False)

# %%
#Check Prods

df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#Join on Product ID

df_ords_prods_merged = df_ords_prods.merge(df_prods, on = "product_id")

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices
# ...

# %%
df_ords_prods_merged.tail()
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32404854                 15                     1.0       43553
# 32404855                 11                     3.0       43553
# 32404856                  7                     NaN       42338
# 32404857                  5                    15.0       42338
# 32404858                 14                     NaN       28818
#
#           add_to_cart_order  reordered _merge  Unnamed: 0  \
# 32404854                  2          1   both       43557
# 32404855                  2          1   both       43557
# ...

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 15)

# %%
#Drop merge flag from 1st merge
df_ords_prods = df_ords_prods.drop('_merge', 1)

# %%
df_ords_prods.shape
# Out:
# (32434489, 9)

# %%
#Join on Product ID, with Merge Flag

df_ords_prods_merged = df_ords_prods.merge(df_prods, on = "product_id", indicator = True)

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge
# ...

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 15)

# %%
#Export merged data set

df_ords_prods_merged.to_pickle(r'C:\Users\18179\Documents\CareerFoundry\InstaCart Basket Analysis\02 Data\orders_products_merged.pkl')
